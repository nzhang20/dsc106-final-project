# %%
import pandas as pd
from urllib.request import urlopen
from json import loads

# %%
url = "https://educationdata.urban.org/api/v1/schools/ccd/directory/1988/"
response = urlopen(url)
data = loads(response.read())

# %%
schools_list = data['results']

df = pd.DataFrame(schools_list)
# Out:
# {'count': 84968,
#  'next': 'https://educationdata.urban.org/api/v1/schools/ccd/directory/1988/?mode=R&page=2',
#  'previous': None,
#  'results': [{'year': 1988,
#    'ncessch': '010000201704',
#    'school_id': '01704',
#    'school_name': 'CHALKVILLE CAMPUS -SEQUOYAH',
#    'leaid': '0100002',
#    'lea_name': 'ALABAMA YOUTH SERVICES',
#    'state_leaid': '210',
#    'seasch': '0020',
#    'street_mailing': 'P O BOX 9486',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35220',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2056818841',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 4,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 14,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 121,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000201704,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000201705',
#    'school_id': '01705',
#    'school_name': 'MT MEIGS CAMPUS - WALLACE',
#    'leaid': '0100002',
#    'lea_name': 'ALABAMA YOUTH SERVICES',
#    'state_leaid': '210',
#    'seasch': '0030',
#    'street_mailing': 'P O BOX 66',
#    'city_mailing': 'MOUNT MEIGS',
#    'state_mailing': '',
#    'zip_mailing': '36057',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052729100',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 4,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 32,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 182,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000201705,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000201706',
#    'school_id': '01706',
#    'school_name': 'VACCA CAMPUS - MCNEEL',
#    'leaid': '0100002',
#    'lea_name': 'ALABAMA YOUTH SERVICES',
#    'state_leaid': '210',
#    'seasch': '0040',
#    'street_mailing': '8950 ROEBUCK BLVD',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35206',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058332361',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 2,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 4,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 15,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 115,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000201706,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000500870',
#    'school_id': '00870',
#    'school_name': 'ALABAMA AVE MIDDLE SCH',
#    'leaid': '0100005',
#    'lea_name': 'ALBERTVILLE CITY',
#    'state_leaid': '101',
#    'seasch': '0010',
#    'street_mailing': '600 E ALABAMA AVE',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058782341',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 6,
#    'highest_grade_offered': 8,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 38,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 777,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000500870,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000500871',
#    'school_id': '00871',
#    'school_name': 'ALBERTVILLE HIGH SCH',
#    'leaid': '0100005',
#    'lea_name': 'ALBERTVILLE CITY',
#    'state_leaid': '101',
#    'seasch': '0020',
#    'street_mailing': 'E MCCORD AVE',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058786600',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 9,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 54,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 971,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000500871,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000500879',
#    'school_id': '00879',
#    'school_name': 'EVANS ELEM SCH',
#    'leaid': '0100005',
#    'lea_name': 'ALBERTVILLE CITY',
#    'state_leaid': '101',
#    'seasch': '0110',
#    'street_mailing': '900 W MCKINNEY AVE',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058787698',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 3,
#    'highest_grade_offered': 5,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 18,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 383,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000500879,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000500886',
#    'school_id': '00886',
#    'school_name': 'MCCORD AVE ELEM SCH',
#    'leaid': '0100005',
#    'lea_name': 'ALBERTVILLE CITY',
#    'state_leaid': '101',
#    'seasch': '0150',
#    'street_mailing': 'E MCCORD AVE',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058786160',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 3,
#    'highest_grade_offered': 5,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 21,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 383,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000500886,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000500889',
#    'school_id': '00889',
#    'school_name': 'WEST END ELEM SCH',
#    'leaid': '0100005',
#    'lea_name': 'ALBERTVILLE CITY',
#    'state_leaid': '101',
#    'seasch': '0200',
#    'street_mailing': '1100 HORTON RD',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058786611',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 2,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 20,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 367,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000500889,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000501616',
#    'school_id': '01616',
#    'school_name': 'BIG SPRING LAKE ELEM SCH',
#    'leaid': '0100005',
#    'lea_name': 'ALBERTVILLE CITY',
#    'state_leaid': '101',
#    'seasch': '0035',
#    'street_mailing': 'RT 9 COUNTRY CLUB RD',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058787922',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 2,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 21,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 404,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000501616,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600872',
#    'school_id': '00872',
#    'school_name': 'ASBURY JR HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0030',
#    'street_mailing': 'STAR RT',
#    'city_mailing': 'ALBERTVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35950',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058784068',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 9,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 17,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 287,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600872,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600873',
#    'school_id': '00873',
#    'school_name': 'BOAZ ELEM SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0040',
#    'street_mailing': '502 SPARKS AVE',
#    'city_mailing': 'BOAZ',
#    'state_mailing': '',
#    'zip_mailing': '35957',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2055933481',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 2,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 28,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 494,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600873,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600874',
#    'school_id': '00874',
#    'school_name': 'BOAZ HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0060',
#    'street_mailing': 'BROWN ST',
#    'city_mailing': 'BOAZ',
#    'state_mailing': '',
#    'zip_mailing': '35957',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2055932401',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 43,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 917,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600874,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600876',
#    'school_id': '00876',
#    'school_name': 'CLAYSVILLE JR HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0070',
#    'street_mailing': 'STAR RT 62 BOX 14',
#    'city_mailing': 'GUNTERSVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35976',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2055824444',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 9,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 22,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 378,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600876,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600877',
#    'school_id': '00877',
#    'school_name': 'DOUGLAS ELEM SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0090',
#    'street_mailing': 'P O BOX 300',
#    'city_mailing': 'DOUGLAS',
#    'state_mailing': '',
#    'zip_mailing': '35964',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2055934420',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 35,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 703,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600877,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600878',
#    'school_id': '00878',
#    'school_name': 'DOUGLAS HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0100',
#    'street_mailing': 'P O BOX 300',
#    'city_mailing': 'DOUGLAS',
#    'state_mailing': '',
#    'zip_mailing': '35964',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2055932810',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 27,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 571,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600878,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600880',
#    'school_id': '00880',
#    'school_name': 'GRASSY JR HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0120',
#    'street_mailing': 'RT 1',
#    'city_mailing': 'ARAB',
#    'state_mailing': '',
#    'zip_mailing': '35016',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2057532246',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 9,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 14,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 225,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600880,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600883',
#    'school_id': '00883',
#    'school_name': 'KATE D SMITH DAR HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0140',
#    'street_mailing': 'RT 3',
#    'city_mailing': 'GRANT',
#    'state_mailing': '',
#    'zip_mailing': '35747',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2057284238',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 25,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 504,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600883,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600884',
#    'school_id': '00884',
#    'school_name': 'CORLEY ELEM SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0080',
#    'street_mailing': 'P O BOX 526',
#    'city_mailing': 'BOAZ',
#    'state_mailing': '',
#    'zip_mailing': '35957',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2055933254',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 3,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 29,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 596,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600884,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000600887',
#    'school_id': '00887',
#    'school_name': 'UNION GROVE JR HIGH SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0180',
#    'street_mailing': 'P O BOX 7',
#    'city_mailing': 'UNION GROVE',
#    'state_mailing': '',
#    'zip_mailing': '35175',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2057532532',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 8,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 14,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 277,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000600887,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000601685',
#    'school_id': '01685',
#    'school_name': 'KATE D SMITH DAR ELEM SCH',
#    'leaid': '0100006',
#    'lea_name': 'MARSHALL COUNTY',
#    'state_leaid': '048',
#    'seasch': '0145',
#    'street_mailing': 'RT 3',
#    'city_mailing': 'GRANT',
#    'state_mailing': '',
#    'zip_mailing': '35747',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2057282226',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 27,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 535,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000601685,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701737',
#    'school_id': '01737',
#    'school_name': 'BERRY HIGH SCHOOL',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0070',
#    'street_mailing': '2826 COLUMBIANA RD',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35216',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058221600',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 9,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 103,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 1291,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701737,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701738',
#    'school_id': '01738',
#    'school_name': 'BLUFF PARK ELEM SCH',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0080',
#    'street_mailing': '569 PARK AVE',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35226',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058220600',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 50,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 714,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701738,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701739',
#    'school_id': '01739',
#    'school_name': 'GREEN VALLEY ELEM SCH',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0350',
#    'street_mailing': '3200 OLD COLUMBIANA RD',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35226',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058222710',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 42,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 410,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701739,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701740',
#    'school_id': '01740',
#    'school_name': 'GWIN ELEM SCH',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0365',
#    'street_mailing': '1580 PATTONS CHAPEL RD',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35226',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058220955',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 30,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 466,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701740,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701741',
#    'school_id': '01741',
#    'school_name': 'IRA F SIMMONS JR HIGH',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0425',
#    'street_mailing': '1575 PATTONS CHAPEL RD',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35226',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2059790996',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 8,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 47,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 723,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701741,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701742',
#    'school_id': '01742',
#    'school_name': 'ROCKY RIDGE ELEM SCH',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0760',
#    'street_mailing': '2876 OLD ROCKY RIDGE',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35243',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058220741',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 43,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 724,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701742,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010000701743',
#    'school_id': '01743',
#    'school_name': 'SHADES MOUNTAIN ELEM SCH',
#    'leaid': '0100007',
#    'lea_name': 'HOOVER CITY',
#    'state_leaid': '158',
#    'seasch': '0810',
#    'street_mailing': '2250 SUMPTER ST',
#    'city_mailing': 'BIRMINGHAM',
#    'state_mailing': '',
#    'zip_mailing': '35226',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058223095',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 3,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 25,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 389,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10000701743,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010003000001',
#    'school_id': '00001',
#    'school_name': 'ALEXANDER CITY JR HIGH SCH',
#    'leaid': '0100030',
#    'lea_name': 'ALEXANDER CITY CITY',
#    'state_leaid': '102',
#    'seasch': '0010',
#    'street_mailing': 'P O BOX 817',
#    'city_mailing': 'ALEXANDER CITY',
#    'state_mailing': '',
#    'zip_mailing': '35010',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052344269',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 8,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 32,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 606,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10003000001,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010003000003',
#    'school_id': '00003',
#    'school_name': 'BENJAMIN RUSSELL HIGH SCH',
#    'leaid': '0100030',
#    'lea_name': 'ALEXANDER CITY CITY',
#    'state_leaid': '102',
#    'seasch': '0020',
#    'street_mailing': 'P O BOX 1029',
#    'city_mailing': 'ALEXANDER CITY',
#    'state_mailing': '',
#    'zip_mailing': '35010',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052345011',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 9,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 50,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 1139,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10003000003,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010003000004',
#    'school_id': '00004',
#    'school_name': 'JIM PEARSON SCHOOL',
#    'leaid': '0100030',
#    'lea_name': 'ALEXANDER CITY CITY',
#    'state_leaid': '102',
#    'seasch': '0030',
#    'street_mailing': 'SCOTT RD',
#    'city_mailing': 'ALEXANDER CITY',
#    'state_mailing': '',
#    'zip_mailing': '35010',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052343371',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 2,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 48,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 880,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10003000004,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010003000005',
#    'school_id': '00005',
#    'school_name': 'NATHANIEL H STEPHENS ELEM',
#    'leaid': '0100030',
#    'lea_name': 'ALEXANDER CITY CITY',
#    'state_leaid': '102',
#    'seasch': '0040',
#    'street_mailing': 'LAUREL ST',
#    'city_mailing': 'ALEXANDER CITY',
#    'state_mailing': '',
#    'zip_mailing': '35010',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052342456',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 3,
#    'highest_grade_offered': 4,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 32,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 639,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10003000005,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010003000006',
#    'school_id': '00006',
#    'school_name': 'WILLIAM L RADNEY ELEM SCH',
#    'leaid': '0100030',
#    'lea_name': 'ALEXANDER CITY CITY',
#    'state_leaid': '102',
#    'seasch': '0050',
#    'street_mailing': '1109 ALISON DR',
#    'city_mailing': 'ALEXANDER CITY',
#    'state_mailing': '',
#    'zip_mailing': '35010',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052343401',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 5,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 25,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 575,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10003000006,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010006000007',
#    'school_id': '00007',
#    'school_name': 'ANDALUSIA HIGH SCH',
#    'leaid': '0100060',
#    'lea_name': 'ANDALUSIA CITY',
#    'state_leaid': '104',
#    'seasch': '0010',
#    'street_mailing': 'P O BOX 220',
#    'city_mailing': 'ANDALUSIA',
#    'state_mailing': '',
#    'zip_mailing': '36420',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052227569',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 9,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 38,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 644,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10006000007,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010006000008',
#    'school_id': '00008',
#    'school_name': 'ANDALUSIA MIDDLE SCH',
#    'leaid': '0100060',
#    'lea_name': 'ANDALUSIA CITY',
#    'state_leaid': '104',
#    'seasch': '0020',
#    'street_mailing': '8TH AVE',
#    'city_mailing': 'ANDALUSIA',
#    'state_mailing': '',
#    'zip_mailing': '36420',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052226542',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 6,
#    'highest_grade_offered': 8,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 27,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 478,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10006000008,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010006000009',
#    'school_id': '00009',
#    'school_name': 'CHURCH STREET SCHOOL',
#    'leaid': '0100060',
#    'lea_name': 'ANDALUSIA CITY',
#    'state_leaid': '104',
#    'seasch': '0030',
#    'street_mailing': '420 CHURCH ST',
#    'city_mailing': 'ANDALUSIA',
#    'state_mailing': '',
#    'zip_mailing': '36420',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2052221224',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 6,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 5,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 31,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 549,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10006000009,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010006000010',
#    'school_id': '00010',
#    'school_name': 'THREE NOTCH SCHOOL',
#    'leaid': '0100060',
#    'lea_name': 'ANDALUSIA CITY',
#    'state_leaid': '104',
#    'seasch': '0040',
#    'street_mailing': '505 E 3 NOTCH ST',
#    'city_mailing': 'ANDALUSIA',
#    'state_mailing': '',
# ...
#    'phone': '2053535214',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 54,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 1,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 1014,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10248001052,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010248001696',
#    'school_id': '01696',
#    'school_name': 'ALBERT P BREWER HIGH SCH',
#    'leaid': '0102480',
#    'lea_name': 'MORGAN COUNTY',
#    'state_leaid': '052',
#    'seasch': '0005',
#    'street_mailing': 'RT 2 BOX 149',
#    'city_mailing': 'SOMERVILLE',
#    'state_mailing': '',
#    'zip_mailing': '35670',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2057788634',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 7,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 9,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 63,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 1173,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10248001696,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010249001053',
#    'school_id': '01053',
#    'school_name': 'BROOKWOOD FOREST ELEM SCH',
#    'leaid': '0102490',
#    'lea_name': 'MOUNTAIN BROOK CITY',
#    'state_leaid': '175',
#    'seasch': '0010',
#    'street_mailing': '3701 S BROOKWOOD RD',
#    'city_mailing': 'MOUNTAIN BROOK',
#    'state_mailing': '',
#    'zip_mailing': '35223',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2059670730',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 28,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 402,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10249001053,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010249001054',
#    'school_id': '01054',
#    'school_name': 'CHEROKEE BEND ELEM SCH',
#    'leaid': '0102490',
#    'lea_name': 'MOUNTAIN BROOK CITY',
#    'state_leaid': '175',
#    'seasch': '0020',
#    'street_mailing': '4400 FAIR OAKS DR',
#    'city_mailing': 'MOUNTAIN BROOK',
#    'state_mailing': '',
#    'zip_mailing': '35213',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058713595',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 27,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 398,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10249001054,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010249001055',
#    'school_id': '01055',
#    'school_name': 'CRESTLINE ELEM SCH',
#    'leaid': '0102490',
#    'lea_name': 'MOUNTAIN BROOK CITY',
#    'state_leaid': '175',
#    'seasch': '0030',
#    'street_mailing': '3785 JACKSON BLVD',
#    'city_mailing': 'MOUNTAIN BROOK',
#    'state_mailing': '',
#    'zip_mailing': '35213',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058718126',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 31,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 498,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10249001055,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010249001056',
#    'school_id': '01056',
#    'school_name': 'MT BROOK HIGH SCH',
#    'leaid': '0102490',
#    'lea_name': 'MOUNTAIN BROOK CITY',
#    'state_leaid': '175',
#    'seasch': '0050',
#    'street_mailing': '3650 BETHUNE DR',
#    'city_mailing': 'MOUNTAIN BROOK',
#    'state_mailing': '',
#    'zip_mailing': '35223',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2059672090',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 10,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 57,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 738,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10249001056,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010249001057',
#    'school_id': '01057',
#    'school_name': 'MT BROOK JR HIGH',
#    'leaid': '0102490',
#    'lea_name': 'MOUNTAIN BROOK CITY',
#    'state_leaid': '175',
#    'seasch': '0060',
#    'street_mailing': '205 OVERBROOK DR',
#    'city_mailing': 'MOUNTAIN BROOK',
#    'state_mailing': '',
#    'zip_mailing': '35213',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058713516',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 7,
#    'highest_grade_offered': 9,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 42,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 656,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10249001057,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010249001058',
#    'school_id': '01058',
#    'school_name': 'MOUNTAIN BROOK ELEM SCH',
#    'leaid': '0102490',
#    'lea_name': 'MOUNTAIN BROOK CITY',
#    'state_leaid': '175',
#    'seasch': '0040',
#    'street_mailing': '3020 CAMBRIDGE RD',
#    'city_mailing': 'MOUNTAIN BROOK',
#    'state_mailing': '',
#    'zip_mailing': '35223',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2058718191',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 6,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 28,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 478,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10249001058,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010252001059',
#    'school_id': '01059',
#    'school_name': 'AVALON MIDDLE SCH',
#    'leaid': '0102520',
#    'lea_name': 'MUSCLE SHOALS CITY',
#    'state_leaid': '176',
#    'seasch': '0010',
#    'street_mailing': '1400 AVALON AVE',
#    'city_mailing': 'MUSCLE SHOALS',
#    'state_mailing': '',
#    'zip_mailing': '35661',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2053837921',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 5,
#    'highest_grade_offered': 8,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 28,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 0,
#    'middle_cedp': 1,
#    'ungrade_cedp': 0,
#    'enrollment': 577,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10252001059,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010252001060',
#    'school_id': '01060',
#    'school_name': 'HIGHLAND PARK ELEM SCH',
#    'leaid': '0102520',
#    'lea_name': 'MUSCLE SHOALS CITY',
#    'state_leaid': '176',
#    'seasch': '0020',
#    'street_mailing': '710 ELMHURST ST',
#    'city_mailing': 'MUSCLE SHOALS',
#    'state_mailing': '',
#    'zip_mailing': '35661',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2053834266',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 4,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 20,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 435,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10252001060,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010252001062',
#    'school_id': '01062',
#    'school_name': 'MUSCLE SHOALS HIGH SCH',
#    'leaid': '0102520',
#    'lea_name': 'MUSCLE SHOALS CITY',
#    'state_leaid': '176',
#    'seasch': '0040',
#    'street_mailing': '1400 AVALON AVE',
#    'city_mailing': 'MUSCLE SHOALS',
#    'state_mailing': '',
#    'zip_mailing': '35661',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2053813950',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 9,
#    'highest_grade_offered': 12,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 31,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 0,
#    'high_cedp': 1,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 565,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10252001062,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   {'year': 1988,
#    'ncessch': '010252001063',
#    'school_id': '01063',
#    'school_name': 'WEBSTER ELEM SCH',
#    'leaid': '0102520',
#    'lea_name': 'MUSCLE SHOALS CITY',
#    'state_leaid': '176',
#    'seasch': '0050',
#    'street_mailing': 'P O BOX 2546 200 WEBSTER',
#    'city_mailing': 'MUSCLE SHOALS',
#    'state_mailing': '',
#    'zip_mailing': '35661',
#    'street_location': '',
#    'city_location': '',
#    'state_location': '',
#    'zip_location': '',
#    'phone': '2053832263',
#    'fips': 1,
#    'latitude': None,
#    'longitude': None,
#    'csa': None,
#    'cbsa': None,
#    'urban_centric_locale': 4,
#    'county_code': None,
#    'school_level': None,
#    'school_type': 1,
#    'school_status': 1,
#    'lowest_grade_offered': 0,
#    'highest_grade_offered': 4,
#    'bureau_indian_education': None,
#    'title_i_status': None,
#    'title_i_eligible': None,
#    'title_i_schoolwide': None,
#    'charter': None,
#    'magnet': None,
#    'shared_time': None,
#    'virtual': None,
#    'teachers_fte': 17,
#    'free_lunch': None,
#    'reduced_price_lunch': None,
#    'free_or_reduced_price_lunch': None,
#    'elem_cedp': 1,
#    'high_cedp': 0,
#    'middle_cedp': 0,
#    'ungrade_cedp': 0,
#    'enrollment': 347,
#    'state_leg_district_lower': '',
#    'state_leg_district_upper': '',
#    'ncessch_num': 10252001063,
#    'congress_district_id': None,
#    'direct_certification': None,
#    'lunch_program': None},
#   ...]}

# %%
df
