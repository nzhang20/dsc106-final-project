# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final_harass_df.csv')
df.groupby(['race', 'year']).sum()
# Out:
#                                                 count
# race                                      year
# American Indian or Alaska Native          2011     12
#                                           2013      0
#                                           2015      4
#                                           2017      0
# Asian                                     2011     12
#                                           2013     12
#                                           2015      0
#                                           2017     12
# Black                                     2011    680
#                                           2013    304
#                                           2015    268
#                                           2017    148
# Hispanic                                  2011     86
#                                           2013     86
#                                           2015     44
# ...

# %%
df = df[df['race'] != 'Native Hawaiian or other Pacific Islander']
df['race'].unique()
# Out:
# array(['American Indian or Alaska Native', 'Asian', 'Black', 'Hispanic',
#        'Two or more races', 'White'], dtype=object)

# %%
df.to_csv('final_harass_df.csv', index=False)

# %%
df = pd.read_csv('final_discipline_df.csv')
df.groupby(['race', 'year']).sum()
# Out:
#                                                 count
# race                                      year
# American Indian or Alaska Native          2011      4
#                                           2013      0
#                                           2015      0
#                                           2017      2
# Asian                                     2011     16
#                                           2013      8
#                                           2015      0
#                                           2017     10
# Black                                     2011    460
#                                           2013    184
#                                           2015    246
#                                           2017     94
# Hispanic                                  2011     40
#                                           2013     30
#                                           2015     16
# ...

# %%
df = df[df['race'] != 'Native Hawaiian or other Pacific Islander']

# %%
df.to_csv('final_discipline_df.csv', index=False)
